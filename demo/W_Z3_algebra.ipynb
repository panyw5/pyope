# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from pyope import *
from fractions import Fraction
import sympy as sp

# %% [markdown]
# # $\mathcal{W}_{\mathbb{Z}_3}$ associated to rank-one $\mathcal{N} = 3$ theory in Zafrir

# %%
# 定义自由场算符
# bc 系统（鬼场）：b 权重 2, c 权重 -1
clear_registry()
b = BasicOperator('b', fermionic=True, conformal_weight=Fraction(2))
c = BasicOperator('c', fermionic=True, conformal_weight=Fraction(-1))

# βγ 系统：β 权重 3/2, γ 权重 -1/2
β = BasicOperator('β',  conformal_weight=Fraction(3, 2))
γ = BasicOperator('γ',  conformal_weight=Fraction(-1, 2))
OPE[b, c] = MakeOPE([One])
OPE[β, γ] = MakeOPE([-One])

# %%
J = 2 * NO(b, c) + 3 * NO(β, γ)

G = NO(γ, b)
Gbar = 2 * NO(d(β), c) + 3 * NO(β, d(c))

T = - 2 * NO(b, d(c)) - Fraction(3,2) * NO(β, d(γ)) - NO(d(b), c) - Fraction(1,2) * NO(d(β), γ)


W = β  # 权重 3/2
GW = b    # 权重 2

Wbar = (NO(β, NO(β, NO(γ, NO(γ, γ))))
      + 2 * NO(β, NO(γ, NO(γ, NO(b, c))))
      - 4 * NO(β, NO(d(γ), γ))
      - Fraction(4, 3) * NO(γ, NO(b, d(c)))
      + Fraction(2, 3) * NO(γ, NO(d(b), c))
      + Fraction(2, 3) * NO(d(β), NO(γ, γ))
      - Fraction(8, 3) * NO(d(γ), NO(b, c))
      + Fraction(10, 9) * d(d(γ)))

GbarWbar = (Fraction(8, 3) * NO(b, NO(d(d(c)), c))
       + 3 * NO(β, NO(β, NO(γ, NO(γ, d(c)))))
       - 4 * NO(β, NO(γ, NO(b, NO(d(c), c))))
       - 4 * NO(β, NO(γ, d(d(c))))
       - 4 * NO(β, NO(d(γ), d(c)))
       - Fraction(2, 3) * NO(d(b), NO(d(c), c))
       + 2 * NO(d(β), NO(β, NO(γ, NO(γ, c))))
       - Fraction(8, 3) * NO(d(β), NO(d(γ), c))
       + Fraction(2, 3) * NO(d(d(β)), NO(γ, c))
       + Fraction(10, 9) * d(d(d(c))))

generators = [T, J, W, Wbar, G, Gbar, GW, GbarWbar]

(T, J, W, Wbar, G, Gbar, GW, GbarWbar) = make_realized(generators)
generators = [T, J, W, Wbar, G, Gbar, GW, GbarWbar]

# %% [markdown]
# ## Null states at weight-8

# %%
null_1 = (
  -Fraction(8, 9) * NO(T,NO(T,NO(T,NO(J,J))))
+ Fraction(4, 3) * NO(T,NO(T,NO(T,T)))
+ Fraction(4, 9) * NO(T,NO(T,NO(T,d(J))))
+ -Fraction(8, 9) * NO(T,NO(T,NO(J,NO(G,Gbar))))
+ Fraction(2, 3) * NO(T,NO(T,NO(G,d(Gbar))))
+ -3 * NO(T,NO(T,NO(W,d(Wbar))))
+ -Fraction(1, 9) * NO(T,NO(T,NO(d(J),NO(J,J))))
+ -Fraction(4, 9) * NO(T,NO(T,NO(d(J),d(J))))
+ -Fraction(2, 9) * NO(T,NO(T,NO(d(G), Gbar)))
+ 5 * NO(T,NO(T,NO(d(W),Wbar)))
+ 1 * NO(T,NO(T,NO(d(J,2),J)))).realize()

simplify_with_wolfram(null_1)
# Out:
# ConstantOperator('Zero')

# %%
null_1 = [(-Fraction(8, 9) * NO(T, NO(T, NO(T, NO(J, J))))
          + Fraction(4, 3) * NO(T, NO(T, NO(T, T)))
          + Fraction(4, 9) * NO(T, NO(T, NO(T, d(J))))
          + -Fraction(8, 9) * NO(T, NO(T, NO(J, NO(G, Gbar))))
          + Fraction(2, 3) * NO(T, NO(T, NO(G, d(Gbar))))
          + -3 * NO(T, NO(T, NO(W, d(Wbar))))
          + -Fraction(1, 9) * NO(T, NO(T, NO(d(J), NO(J, J))))
          + -Fraction(4, 9) * NO(T, NO(T, NO(d(J), d(J))))
          + -Fraction(2, 9) * NO(T, NO(T, NO(d(G), Gbar)))
          + 5 * NO(T, NO(T, NO(d(W), Wbar)))
          + 1 * NO(T, NO(T, NO(d(J, 2), J)))).realize(),
          
          (-Fraction(8, 9) * NO(T, NO(T, NO(T, NO(J, J))))
          + Fraction(4, 3) * NO(T, NO(T, NO(T, T)))
          + Fraction(4, 9) * NO(T, NO(T, NO(T, d(J))))
          + -Fraction(8, 9) * NO(T, NO(T, NO(J, NO(G, Gbar))))
          + Fraction(2, 3) * NO(T, NO(T, NO(G, d(Gbar))))
          + -3 * NO(T, NO(T, NO(W, d(Wbar))))
          + -Fraction(1, 9) * NO(T, NO(T, NO(d(J), NO(J, J))))
          + -Fraction(4, 9) * NO(T, NO(T, NO(d(J), d(J))))
          + -Fraction(2, 9) * NO(T, NO(T, NO(d(G), Gbar)))
          + 5 * NO(T, NO(T, NO(d(W), Wbar)))
          + 1 * NO(T, NO(T, NO(d(J, 2), J)))).realize()]

simplify_with_wolfram(null_1)

# %% [markdown]
# ## Basis

# %%
# 用 generators 所生成的算符空间
weight=4
basis = LocalOperatorBasis(generators)


# 用 b, c, β, γ 所生成的算符空间
bc_basis = LocalOperatorBasis([b, c, β, γ], max_occurence=6)

# 列举 weight=4 的算符，有 10 个
list_of_ops = [op for op in basis.list(weight=weight)]
list_of_ops_realized = [op.realize() for op in basis.list(weight=weight)]
len(list_of_ops)

independents = bc_basis.list_independent_ops(list_of_ops_realized)
independents_indices = bc_basis.list_independent_op_indices(list_of_ops_realized)
relations = bc_basis.list_zero_relations(list_of_ops_realized)

# %%
weight=4
basis = LocalOperatorBasis(generators)


# 用 b, c, β, γ 所生成的算符空间
bc_basis = LocalOperatorBasis([b, c, β, γ], max_occurence=6)

# 列举 weight=4 的算符，有 10 个
list_of_ops = [op for op in basis.list(weight=weight)]
list_of_ops_realized = [op.realize() for op in basis.list(weight=weight)]
list_of_ops_realized = simplify_with_wolfram(list_of_ops_realized)

# %%
bc_basis.list_independent_ops(list_of_ops_realized)
# Out:
# [∂^5c - 8*NO(b,NO(∂^3c,NO(c,NO(β,γ))))/3 + 28*NO(b,NO(∂^3c,∂c))/9 + 20*NO(b,NO(∂^4c,c))/9 - 12*NO(b,NO(∂c,NO(c,NO(β,NO(β,NO(∂γ,γ)))))) + 2*NO(b,NO(∂c,NO(c,NO(β,∂^2γ)))) - 26*NO(b,NO(∂c,NO(c,NO(∂^2β,γ))))/3 - 8*NO(b,NO(∂c,NO(c,NO(∂β,NO(β,NO(γ,γ)))))) - 40*NO(b,NO(∂c,NO(c,NO(∂β,∂γ))))/3 + 10*NO(c,NO(∂^2β,NO(β,NO(∂γ,γ)))) + 11*NO(c,NO(∂^2β,NO(∂β,NO(γ,γ)))) - 17*NO(c,NO(∂^2β,∂^2γ))/3 + 3*NO(c,NO(∂^3β,NO(β,NO(γ,γ)))) - 8*NO(c,NO(∂^3β,∂γ))/3 + 5*NO(c,NO(∂^4β,γ))/6 + 6*NO(c,NO(∂β,NO(β,NO(β,NO(∂γ,NO(γ,γ)))))) - 2*NO(c,NO(∂β,NO(β,NO(∂^2γ,γ)))) - 4*NO(c,NO(∂β,NO(β,NO(∂γ,∂γ)))) + 6*NO(c,NO(∂β,NO(∂β,NO(β,NO(γ,NO(γ,γ)))))) - 4*NO(c,NO(∂β,∂^3γ))/3 + 4*NO(∂^2b,NO(∂^2c,c)) - 8*NO(∂^2b,NO(∂c,NO(c,NO(β,γ)))) - 6*NO(∂^2c,NO(β,∂^2γ)) - 10*NO(∂^2c,NO(∂^2β,γ)) - 16*NO(∂^2c,NO(∂β,∂γ)) - 8*NO(∂^3b,NO(∂c,c))/9 + 2*NO(∂^3c,NO(β,NO(β,NO(γ,γ)))) - 22*NO(∂^3c,NO(β,∂γ))/3 - 14*NO(∂^3c,NO(∂β,γ))/3 - 10*NO(∂^4c,NO(β,γ))/3 + 4*NO(∂b,NO(∂^2c,∂c)) + 8*NO(∂b,NO(∂^3c,c))/3 - 6*NO(∂b,NO(∂c,NO(c,NO(β,NO(β,NO(γ,γ)))))) - 2*NO(∂b,NO(∂c,NO(c,NO(β,∂γ)))) - 10*NO(∂b,NO(∂c,NO(c,NO(∂β,γ)))) + 9*NO(∂c,NO(β,NO(β,NO(β,NO(∂γ,NO(γ,γ)))))) - 3*NO(∂c,NO(β,NO(β,NO(∂^2γ,γ)))) - 6*NO(∂c,NO(β,NO(β,NO(∂γ,∂γ)))) - 2*NO(∂c,NO(β,∂^3γ)) + 19*NO(∂c,NO(∂^2β,NO(β,NO(γ,γ)))) - 14*NO(∂c,NO(∂^2β,∂γ)) + 4*NO(∂c,NO(∂^3β,γ))/3 + 9*NO(∂c,NO(∂β,NO(β,NO(β,NO(γ,NO(γ,γ)))))) + 20*NO(∂c,NO(∂β,NO(β,NO(∂γ,γ)))) + 10*NO(∂c,NO(∂β,NO(∂β,NO(γ,γ)))) - 40*NO(∂c,NO(∂β,∂^2γ))/3,
#  -18*NO(b,NO(c,NO(β,NO(β,NO(∂γ,γ))))) + 9*NO(b,NO(c,NO(β,∂^2γ))) - 3*NO(b,NO(c,NO(∂^2β,γ))) - 6*NO(b,NO(c,NO(∂β,NO(β,NO(γ,γ))))) - 12*NO(b,NO(c,NO(∂β,∂γ))) + 12*NO(b,NO(∂^2c,NO(β,γ))) - 18*NO(b,NO(∂c,NO(β,NO(β,NO(γ,γ))))) + 24*NO(b,NO(∂c,NO(β,∂γ))) - 16*NO(b,NO(∂c,NO(∂β,γ))) - 4*NO(b,∂^3c)/3 - 27*NO(β,NO(β,NO(β,NO(∂γ,NO(γ,γ)))))/2 + 27*NO(β,NO(β,NO(∂^2γ,γ)))/2 + 27*NO(β,NO(β,NO(∂γ,∂γ)))/2 - 9*NO(β,∂^3γ)/4 - 6*NO(∂^2b,NO(c,NO(β,γ))) - 9*NO(∂^2β,NO(β,NO(γ,γ)))/2 - 9*NO(∂^2β,∂γ)/4 - 2*NO(∂^3b,c)/3 - 3*NO(∂^3β,γ)/4 + 4*NO(∂b,NO(b,NO(∂c,c))) - 9*NO(∂b,NO(c,NO(β,NO(β,NO(γ,γ))))) + 3*NO(∂b,NO(c,NO(β,∂γ))) - 11*NO(∂b,NO(c,NO(∂β,γ))) - 12*NO(∂b,NO(∂c,NO(β,γ))) + 6*NO(∂b,∂^2c) - 9*NO(∂β,NO(β,NO(β,NO(γ,NO(γ,γ)))))/2 - 27*NO(∂β,NO(β,NO(∂γ,γ))) - 9*NO(∂β,NO(∂β,NO(γ,γ)))/2 + 45*NO(∂β,∂^2γ)/4,
#  -2*NO(b,∂^3c) - 3*NO(β,∂^3γ)/2 - 4*NO(∂^2b,∂c) - 5*NO(∂^2β,∂γ)/2 - NO(∂^3b,c) - NO(∂^3β,γ)/2 - 5*NO(∂b,∂^2c) - 7*NO(∂β,∂^2γ)/2,
#  -3*NO(b,NO(c,NO(β,∂^2γ))) - NO(b,NO(c,NO(∂^2β,γ))) - 4*NO(b,NO(c,NO(∂β,∂γ))) - 6*NO(b,NO(∂^2c,NO(β,γ))) + 4*NO(b,∂^3c)/3 - 9*NO(β,NO(β,NO(∂^2γ,γ)))/2 + 3*NO(β,∂^3γ)/2 - 3*NO(∂^2b,NO(c,NO(β,γ))) - NO(∂^2b,∂c) - 3*NO(∂^2β,NO(β,NO(γ,γ)))/2 - 3*NO(∂^2β,∂γ)/2 - 2*NO(∂^3b,c)/3 - NO(∂^3β,γ)/2 + 6*NO(∂b,NO(b,NO(∂c,c))) - 9*NO(∂b,NO(∂c,NO(β,γ))) - NO(∂b,∂^2c) - 6*NO(∂β,NO(β,NO(∂γ,γ))) - 3*NO(∂β,∂^2γ)/2,
#  -6*NO(b,NO(∂c,NO(c,NO(β,β)))) + NO(c,NO(∂^2β,β)) + 6*NO(c,NO(∂β,NO(β,NO(β,γ)))) + 6*NO(c,NO(∂β,∂β)) - 6*NO(∂^2c,NO(β,β)) + 9*NO(∂c,NO(β,NO(β,NO(β,γ)))) + 9*NO(∂c,NO(∂β,β)),
#  -9*NO(b,NO(∂c,NO(β,∂γ))) - 7*NO(b,NO(∂c,NO(∂β,γ))) + 2*NO(b,∂^3c)/3 - 9*NO(β,NO(β,NO(∂γ,∂γ)))/2 + 3*NO(β,∂^3γ)/4 - 2*NO(∂^2b,∂c) - 9*NO(∂^2β,∂γ)/4 - NO(∂^3b,c)/3 - NO(∂^3β,γ)/4 - 6*NO(∂b,NO(b,NO(∂c,c))) - 6*NO(∂b,NO(c,NO(β,∂γ))) - 4*NO(∂b,NO(c,NO(∂β,γ))) + NO(∂b,∂^2c) - 6*NO(∂β,NO(β,NO(∂γ,γ))) - 3*NO(∂β,NO(∂β,NO(γ,γ)))/2 + 3*NO(∂β,∂^2γ)/4,
#  -∂^5c/6 - 6*NO(b,NO(∂^2c,NO(c,NO(β,NO(β,NO(γ,γ)))))) + 8*NO(b,NO(∂^2c,NO(c,NO(β,∂γ)))) + 4*NO(b,NO(∂^2c,NO(∂c,NO(β,γ)))) + 14*NO(b,NO(∂^3c,NO(c,NO(β,γ))))/3 - 14*NO(b,NO(∂^3c,∂c))/9 - 8*NO(b,NO(∂^4c,c))/9 - 8*NO(b,NO(∂c,NO(c,NO(∂^2β,γ))))/3 - 10*NO(b,NO(∂c,NO(c,NO(∂β,NO(β,NO(γ,γ)))))) + 40*NO(b,NO(∂c,NO(c,NO(∂β,∂γ))))/3 + 2*NO(c,NO(∂^2β,NO(β,NO(β,NO(γ,NO(γ,γ)))))) - 8*NO(c,NO(∂^2β,NO(β,NO(∂γ,γ)))) + 4*NO(c,NO(∂^2β,NO(∂β,NO(γ,γ))))/3 + 20*NO(c,NO(∂^2β,∂^2γ))/9 + NO(c,NO(∂^3β,NO(β,NO(γ,γ)))) - 4*NO(c,NO(∂^3β,∂γ))/3 + NO(c,NO(∂^4β,γ))/18 + 3*NO(∂^2c,NO(β,NO(β,NO(β,NO(γ,NO(γ,γ)))))) - 12*NO(∂^2c,NO(β,NO(β,NO(∂γ,γ)))) + 10*NO(∂^2c,NO(β,∂^2γ))/3 + 2*NO(∂^2c,NO(∂β,NO(β,NO(γ,γ)))) - 7*NO(∂^3c,NO(β,NO(β,NO(γ,γ))))/2 + 14*NO(∂^3c,NO(β,∂γ))/3 - 14*NO(∂^3c,NO(∂β,γ))/9 + 4*NO(∂^4c,NO(β,γ))/3 - 2*NO(∂b,NO(∂^2c,NO(c,NO(β,γ)))) + 7*NO(∂b,NO(∂^3c,c))/9 - 10*NO(∂b,NO(∂c,NO(c,NO(∂β,γ))))/3 - 2*NO(∂c,NO(∂^3β,γ))/3 + 5*NO(∂c,NO(∂β,NO(β,NO(β,NO(γ,NO(γ,γ)))))) - 20*NO(∂c,NO(∂β,NO(β,NO(∂γ,γ)))) + 10*NO(∂c,NO(∂β,NO(∂β,NO(γ,γ))))/3 + 50*NO(∂c,NO(∂β,∂^2γ))/9,
#  -3*NO(b,NO(β,∂γ))/2 - NO(b,NO(∂β,γ))/2 + NO(∂b,NO(b,c)),
#  -7*∂^5c/18 + 8*NO(b,NO(∂^2c,NO(c,NO(β,∂γ)))) + 16*NO(b,NO(∂^2c,NO(c,NO(∂β,γ))))/3 + 4*NO(b,NO(∂^2c,NO(∂c,NO(β,γ)))) + 10*NO(b,NO(∂^3c,NO(c,NO(β,γ))))/3 - 10*NO(b,NO(∂^3c,∂c))/3 - 4*NO(b,NO(∂^4c,c))/3 - 12*NO(b,NO(∂c,NO(c,NO(β,NO(β,NO(∂γ,γ)))))) + 8*NO(b,NO(∂c,NO(c,NO(β,∂^2γ)))) - 2*NO(b,NO(∂c,NO(c,NO(∂β,NO(β,NO(γ,γ)))))) - 8*NO(b,NO(∂c,NO(c,NO(∂β,∂γ)))) + 2*NO(c,NO(∂^2β,NO(β,NO(∂γ,γ)))) + 7*NO(c,NO(∂^2β,NO(∂β,NO(γ,γ))))/3 - 4*NO(c,NO(∂^2β,∂^2γ))/3 - NO(c,NO(∂^4β,γ))/18 + 6*NO(c,NO(∂β,NO(β,NO(β,NO(∂γ,NO(γ,γ)))))) - 8*NO(c,NO(∂β,NO(β,NO(∂^2γ,γ)))) - 8*NO(c,NO(∂β,NO(β,NO(∂γ,∂γ)))) + 4*NO(c,NO(∂β,NO(∂β,NO(β,NO(γ,NO(γ,γ)))))) - 16*NO(c,NO(∂β,NO(∂β,NO(∂γ,γ))))/3 + 20*NO(c,NO(∂β,∂^3γ))/9 + 4*NO(∂^2b,NO(∂^2c,c))/3 - 2*NO(∂^2b,NO(∂c,NO(c,NO(β,γ)))) - 12*NO(∂^2c,NO(β,NO(β,NO(∂γ,γ)))) + 8*NO(∂^2c,NO(β,∂^2γ)) - 10*NO(∂^2c,NO(∂^2β,γ))/3 - 12*NO(∂^2c,NO(∂β,NO(β,NO(γ,γ)))) + 16*NO(∂^2c,NO(∂β,∂γ))/3 - 5*NO(∂^3c,NO(β,NO(β,NO(γ,γ))))/2 + 20*NO(∂^3c,NO(β,∂γ))/3 + 20*NO(∂^3c,NO(∂β,γ))/9 + 2*NO(∂^4c,NO(β,γ)) + 8*NO(∂b,NO(∂^2c,NO(c,NO(β,γ)))) - 4*NO(∂b,NO(∂^2c,∂c))/3 - 5*NO(∂b,NO(∂^3c,c))/3 - 6*NO(∂b,NO(∂c,NO(c,NO(β,NO(β,NO(γ,γ)))))) + 6*NO(∂b,NO(∂c,NO(c,NO(β,∂γ)))) - 4*NO(∂b,NO(∂c,NO(c,NO(∂β,γ))))/3 + 9*NO(∂c,NO(β,NO(β,NO(β,NO(∂γ,NO(γ,γ)))))) - 12*NO(∂c,NO(β,NO(β,NO(∂^2γ,γ)))) - 12*NO(∂c,NO(β,NO(β,NO(∂γ,∂γ)))) + 10*NO(∂c,NO(β,∂^3γ))/3 + 3*NO(∂c,NO(∂^2β,NO(β,NO(γ,γ)))) - 2*NO(∂c,NO(∂^2β,∂γ)) + 6*NO(∂c,NO(∂β,NO(β,NO(β,NO(γ,NO(γ,γ)))))) - 8*NO(∂c,NO(∂β,NO(β,NO(∂γ,γ)))),
#  10*NO(b,NO(c,NO(β,NO(β,NO(β,NO(∂γ,NO(γ,NO(γ,NO(γ,γ))))))))) - 56*NO(b,NO(c,NO(β,NO(β,NO(∂^2γ,NO(γ,NO(γ,γ)))))))/3 - 56*NO(b,NO(c,NO(β,NO(β,NO(∂γ,NO(∂γ,NO(γ,γ))))))) + 616*NO(b,NO(c,NO(β,NO(∂^2γ,NO(∂γ,γ)))))/9 + 56*NO(b,NO(c,NO(β,NO(∂^3γ,NO(γ,γ)))))/9 + 28*NO(b,NO(c,NO(β,NO(∂γ,NO(∂γ,∂γ))))) + 22*NO(b,NO(c,NO(∂^2β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))))/3 - 160*NO(b,NO(c,NO(∂^2β,NO(∂γ,NO(γ,γ)))))/9 - 224*NO(b,NO(c,NO(∂^2γ,∂^2γ)))/27 + 4*NO(b,NO(c,NO(∂^3β,NO(γ,NO(γ,γ)))))/3 - 224*NO(b,NO(c,NO(∂^3γ,∂γ)))/27 + 6*NO(b,NO(c,NO(∂β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,γ))))))))) - 8*NO(b,NO(c,NO(∂β,NO(β,NO(∂γ,NO(γ,NO(γ,γ))))))) - 140*NO(b,NO(c,NO(∂β,NO(∂^2γ,NO(γ,γ)))))/9 + 22*NO(b,NO(c,NO(∂β,NO(∂β,NO(γ,NO(γ,NO(γ,γ)))))))/3 - 140*NO(b,NO(c,NO(∂β,NO(∂γ,NO(∂γ,γ)))))/9 - 7*NO(b,NO(∂^2c,NO(β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))))/3 + 14*NO(b,NO(∂^2c,NO(β,NO(∂γ,NO(γ,γ))))) - 112*NO(b,NO(∂^2c,NO(∂^2γ,γ)))/27 - 14*NO(b,NO(∂^2c,NO(∂β,NO(γ,NO(γ,γ)))))/9 - 56*NO(b,NO(∂^2c,NO(∂γ,∂γ)))/9 + 2*NO(b,NO(∂c,NO(β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,γ))))))))) - 28*NO(b,NO(∂c,NO(β,NO(β,NO(∂γ,NO(γ,NO(γ,γ))))))) + 182*NO(b,NO(∂c,NO(β,NO(∂^2γ,NO(γ,γ)))))/9 + 56*NO(b,NO(∂c,NO(β,NO(∂γ,NO(∂γ,γ))))) - 2*NO(b,NO(∂c,NO(∂^2β,NO(γ,NO(γ,γ)))))/9 - 224*NO(b,NO(∂c,NO(∂^2γ,∂γ)))/9 - 112*NO(b,NO(∂c,NO(∂^3γ,γ)))/27 + 8*NO(b,NO(∂c,NO(∂β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))))/3 - 112*NO(b,NO(∂c,NO(∂β,NO(∂γ,NO(γ,γ)))))/9 + 3*NO(β,NO(β,NO(β,NO(β,NO(∂γ,NO(γ,NO(γ,NO(γ,NO(γ,γ))))))))) - 7*NO(β,NO(β,NO(β,NO(∂^2γ,NO(γ,NO(γ,NO(γ,γ))))))) - 28*NO(β,NO(β,NO(β,NO(∂γ,NO(∂γ,NO(γ,NO(γ,γ))))))) + 154*NO(β,NO(β,NO(∂^2γ,NO(∂γ,NO(γ,γ)))))/3 + 28*NO(β,NO(β,NO(∂^3γ,NO(γ,NO(γ,γ)))))/9 + 42*NO(β,NO(β,NO(∂γ,NO(∂γ,NO(∂γ,γ))))) - 112*NO(β,NO(∂^2γ,NO(∂^2γ,γ)))/9 - 280*NO(β,NO(∂^2γ,NO(∂γ,∂γ)))/9 - 112*NO(β,NO(∂^3γ,NO(∂γ,γ)))/9 + 28*NO(∂^2b,NO(b,NO(∂c,NO(c,NO(γ,γ)))))/9 + 11*NO(∂^2b,NO(c,NO(β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))))/3 - 44*NO(∂^2b,NO(c,NO(β,NO(∂γ,NO(γ,γ)))))/3 - 28*NO(∂^2b,NO(c,NO(∂^2γ,γ)))/27 + 64*NO(∂^2b,NO(c,NO(∂β,NO(γ,NO(γ,γ)))))/9 + 70*NO(∂^2b,NO(c,NO(∂γ,∂γ)))/9 - 7*NO(∂^2b,NO(∂^2c,NO(γ,γ)))/9 - 10*NO(∂^2b,NO(∂c,NO(β,NO(γ,NO(γ,γ)))))/3 + 56*NO(∂^2b,NO(∂c,NO(∂γ,γ)))/9 + 11*NO(∂^2β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,γ)))))))/3 - 18*NO(∂^2β,NO(β,NO(∂γ,NO(γ,NO(γ,γ))))) - 49*NO(∂^2β,NO(∂^2γ,NO(γ,γ)))/27 + 64*NO(∂^2β,NO(∂β,NO(γ,NO(γ,NO(γ,γ)))))/9 + 14*NO(∂^2β,NO(∂γ,NO(∂γ,γ))) + 4*NO(∂^3b,NO(c,NO(β,NO(γ,NO(γ,γ)))))/3 - 74*NO(∂^3b,NO(c,NO(∂γ,γ)))/27 - 16*NO(∂^3b,NO(∂c,NO(γ,γ)))/27 + 4*NO(∂^3β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))/3 - 10*NO(∂^3β,NO(∂γ,NO(γ,γ)))/3 + 280*NO(∂^3γ,∂^2γ)/81 + 5*NO(∂^4b,NO(c,NO(γ,γ)))/27 + 5*NO(∂^4β,NO(γ,NO(γ,γ)))/27 + 28*NO(∂b,NO(b,NO(∂^2c,NO(c,NO(γ,γ)))))/9 + 56*NO(∂b,NO(b,NO(∂c,NO(c,NO(∂γ,γ)))))/9 + 2*NO(∂b,NO(c,NO(β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,γ))))))))) - 4*NO(∂b,NO(c,NO(β,NO(β,NO(∂γ,NO(γ,NO(γ,γ))))))) - 112*NO(∂b,NO(c,NO(β,NO(∂^2γ,NO(γ,γ)))))/9 - 28*NO(∂b,NO(c,NO(β,NO(∂γ,NO(∂γ,γ)))))/3 + 64*NO(∂b,NO(c,NO(∂^2β,NO(γ,NO(γ,γ)))))/9 + 140*NO(∂b,NO(c,NO(∂^2γ,∂γ)))/9 + 56*NO(∂b,NO(c,NO(∂^3γ,γ)))/27 + 44*NO(∂b,NO(c,NO(∂β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))))/3 - 208*NO(∂b,NO(c,NO(∂β,NO(∂γ,NO(γ,γ)))))/9 - 14*NO(∂b,NO(∂^2c,NO(β,NO(γ,NO(γ,γ)))))/3 + 98*NO(∂b,NO(∂^2c,NO(∂γ,γ)))/9 + 4*NO(∂b,NO(∂c,NO(β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))))/3 - 56*NO(∂b,NO(∂c,NO(β,NO(∂γ,NO(γ,γ)))))/3 + 238*NO(∂b,NO(∂c,NO(∂^2γ,γ)))/27 - 4*NO(∂b,NO(∂c,NO(∂β,NO(γ,NO(γ,γ)))))/9 + 140*NO(∂b,NO(∂c,NO(∂γ,∂γ)))/9 + 2*NO(∂β,NO(β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,NO(γ,γ))))))))) - 8*NO(∂β,NO(β,NO(β,NO(∂γ,NO(γ,NO(γ,NO(γ,γ)))))))/3 - 154*NO(∂β,NO(β,NO(∂^2γ,NO(γ,NO(γ,γ)))))/9 - 28*NO(∂β,NO(β,NO(∂γ,NO(∂γ,NO(γ,γ))))) + 952*NO(∂β,NO(∂^2γ,NO(∂γ,γ)))/27 + 56*NO(∂β,NO(∂^3γ,NO(γ,γ)))/27 + 22*NO(∂β,NO(∂β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,γ)))))))/3 - 106*NO(∂β,NO(∂β,NO(∂γ,NO(γ,NO(γ,γ)))))/9 + 140*NO(∂β,NO(∂γ,NO(∂γ,∂γ)))/9,
#  12*NO(b,NO(∂c,NO(β,∂γ))) + 12*NO(b,NO(∂c,NO(∂β,γ))) - 2*NO(b,∂^3c)/3 + 9*NO(β,NO(β,NO(∂γ,∂γ))) - 3*NO(β,∂^3γ)/2 + 2*NO(∂^2b,∂c) + 9*NO(∂^2β,∂γ)/2 + 2*NO(∂^3b,c)/3 + 3*NO(∂^3β,γ)/2 + 8*NO(∂b,NO(b,NO(∂c,c))) + 12*NO(∂b,NO(c,NO(β,∂γ))) + 12*NO(∂b,NO(c,NO(∂β,γ))) - 2*NO(∂b,∂^2c) + 18*NO(∂β,NO(β,NO(∂γ,γ))) + 9*NO(∂β,NO(∂β,NO(γ,γ))) - 9*NO(∂β,∂^2γ)/2,
#  14*NO(b,NO(c,NO(β,NO(β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,NO(γ,γ))))))))))) - 200*NO(b,NO(c,NO(β,NO(β,NO(β,NO(∂γ,NO(γ,NO(γ,NO(γ,γ))))))))) + 952*NO(b,NO(c,NO(β,NO(β,NO(∂^2γ,NO(γ,NO(γ,γ)))))))/9 + 588*NO(b,NO(c,NO(β,NO(β,NO(∂γ,NO(∂γ,NO(γ,γ))))))) - 3080*NO(b,NO(c,NO(β,NO(∂^2γ,NO(∂γ,γ)))))/9 - 112*NO(b,NO(c,NO(β,NO(∂^3γ,NO(γ,γ)))))/9 - 1736*NO(b,NO(c,NO(β,NO(∂γ,NO(∂γ,∂γ)))))/9 + 106*NO(b,NO(c,NO(∂^2β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))))/3 - 944*NO(b,NO(c,NO(∂^2β,NO(∂γ,NO(γ,γ)))))/9 + 2576*NO(b,NO(c,NO(∂^2γ,∂^2γ)))/81 + 92*NO(b,NO(c,NO(∂^3β,NO(γ,NO(γ,γ)))))/27 + 448*NO(b,NO(c,NO(∂^3γ,∂γ)))/27 + 284*NO(b,NO(c,NO(∂β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,γ)))))))))/3 - 624*NO(b,NO(c,NO(∂β,NO(β,NO(∂γ,NO(γ,NO(γ,γ))))))) + 2996*NO(b,NO(c,NO(∂β,NO(∂^2γ,NO(γ,γ)))))/27 + 500*NO(b,NO(c,NO(∂β,NO(∂β,NO(γ,NO(γ,NO(γ,γ)))))))/9 + 4648*NO(b,NO(c,NO(∂β,NO(∂γ,NO(∂γ,γ)))))/9 + 14*NO(b,NO(∂^2c,NO(β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))))/3 - 28*NO(b,NO(∂^2c,NO(β,NO(∂γ,NO(γ,γ))))) + 224*NO(b,NO(∂^2c,NO(∂^2γ,γ)))/27 + 28*NO(b,NO(∂^2c,NO(∂β,NO(γ,NO(γ,γ)))))/9 + 112*NO(b,NO(∂^2c,NO(∂γ,∂γ)))/9 - 22*NO(b,NO(∂c,NO(β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,γ))))))))) + 644*NO(b,NO(∂c,NO(β,NO(β,NO(∂γ,NO(γ,NO(γ,γ)))))))/3 - 826*NO(b,NO(∂c,NO(β,NO(∂^2γ,NO(γ,γ)))))/9 - 952*NO(b,NO(∂c,NO(β,NO(∂γ,NO(∂γ,γ)))))/3 - 10*NO(b,NO(∂c,NO(∂^2β,NO(γ,NO(γ,γ))))) + 2576*NO(b,NO(∂c,NO(∂^2γ,∂γ)))/27 + 224*NO(b,NO(∂c,NO(∂^3γ,γ)))/27 - 200*NO(b,NO(∂c,NO(∂β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))))/3 + 1792*NO(b,NO(∂c,NO(∂β,NO(∂γ,NO(γ,γ)))))/9 + 3*NO(β,NO(β,NO(β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,NO(γ,NO(γ,γ))))))))))) - 60*NO(β,NO(β,NO(β,NO(β,NO(∂γ,NO(γ,NO(γ,NO(γ,NO(γ,γ))))))))) + 119*NO(β,NO(β,NO(β,NO(∂^2γ,NO(γ,NO(γ,NO(γ,γ)))))))/3 + 294*NO(β,NO(β,NO(β,NO(∂γ,NO(∂γ,NO(γ,NO(γ,γ))))))) - 770*NO(β,NO(β,NO(∂^2γ,NO(∂γ,NO(γ,γ)))))/3 - 56*NO(β,NO(β,NO(∂^3γ,NO(γ,NO(γ,γ)))))/9 - 868*NO(β,NO(β,NO(∂γ,NO(∂γ,NO(∂γ,γ)))))/3 + 1288*NO(β,NO(∂^2γ,NO(∂^2γ,γ)))/27 + 392*NO(β,NO(∂^2γ,NO(∂γ,∂γ)))/3 + 224*NO(β,NO(∂^3γ,NO(∂γ,γ)))/9 + 28*NO(∂^2b,NO(b,NO(∂c,NO(c,NO(γ,γ)))))/3 + 46*NO(∂^2b,NO(c,NO(β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))))/3 - 80*NO(∂^2b,NO(c,NO(β,NO(∂γ,NO(γ,γ))))) + 364*NO(∂^2b,NO(c,NO(∂^2γ,γ)))/27 + 176*NO(∂^2b,NO(c,NO(∂β,NO(γ,NO(γ,γ)))))/9 + 364*NO(∂^2b,NO(c,NO(∂γ,∂γ)))/9 + 14*NO(∂^2b,NO(∂^2c,NO(γ,γ)))/9 - 58*NO(∂^2b,NO(∂c,NO(β,NO(γ,NO(γ,γ)))))/3 + 392*NO(∂^2b,NO(∂c,NO(∂γ,γ)))/9 + 19*NO(∂^2β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,γ))))))) - 376*NO(∂^2β,NO(β,NO(∂γ,NO(γ,NO(γ,γ)))))/3 + 161*NO(∂^2β,NO(∂^2γ,NO(γ,γ)))/9 + 76*NO(∂^2β,NO(∂β,NO(γ,NO(γ,NO(γ,γ)))))/3 + 112*NO(∂^2β,NO(∂γ,NO(∂γ,γ))) + 26*NO(∂^3b,NO(c,NO(β,NO(γ,NO(γ,γ)))))/9 - 172*NO(∂^3b,NO(c,NO(∂γ,γ)))/27 - 16*NO(∂^3b,NO(∂c,NO(γ,γ)))/9 + 34*NO(∂^3β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))/9 - 100*NO(∂^3β,NO(∂γ,NO(γ,γ)))/9 - 560*NO(∂^3γ,∂^2γ)/81 + 5*NO(∂^4b,NO(c,NO(γ,γ)))/27 + 5*NO(∂^4β,NO(γ,NO(γ,γ)))/18 - 56*NO(∂b,NO(b,NO(∂^2c,NO(c,NO(γ,γ)))))/9 + 112*NO(∂b,NO(b,NO(∂c,NO(c,NO(β,NO(γ,NO(γ,γ)))))))/3 - 728*NO(∂b,NO(b,NO(∂c,NO(c,NO(∂γ,γ)))))/9 + 30*NO(∂b,NO(c,NO(β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,γ))))))))) - 824*NO(∂b,NO(c,NO(β,NO(β,NO(∂γ,NO(γ,NO(γ,γ)))))))/3 + 280*NO(∂b,NO(c,NO(β,NO(∂^2γ,NO(γ,γ)))))/3 + 1204*NO(∂b,NO(c,NO(β,NO(∂γ,NO(∂γ,γ)))))/3 + 68*NO(∂b,NO(c,NO(∂^2β,NO(γ,NO(γ,γ)))))/3 - 2996*NO(∂b,NO(c,NO(∂^2γ,∂γ)))/27 - 112*NO(∂b,NO(c,NO(∂^3γ,γ)))/27 + 108*NO(∂b,NO(c,NO(∂β,NO(β,NO(γ,NO(γ,NO(γ,γ))))))) - 2728*NO(∂b,NO(c,NO(∂β,NO(∂γ,NO(γ,γ)))))/9 + 28*NO(∂b,NO(∂^2c,NO(β,NO(γ,NO(γ,γ)))))/3 - 196*NO(∂b,NO(∂^2c,NO(∂γ,γ)))/9 - 52*NO(∂b,NO(∂c,NO(β,NO(β,NO(γ,NO(γ,NO(γ,γ))))))) + 280*NO(∂b,NO(∂c,NO(β,NO(∂γ,NO(γ,γ))))) - 518*NO(∂b,NO(∂c,NO(∂^2γ,γ)))/9 - 172*NO(∂b,NO(∂c,NO(∂β,NO(γ,NO(γ,γ)))))/3 - 1204*NO(∂b,NO(∂c,NO(∂γ,∂γ)))/9 + 34*NO(∂β,NO(β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,NO(γ,γ))))))))) - 376*NO(∂β,NO(β,NO(β,NO(∂γ,NO(γ,NO(γ,NO(γ,γ))))))) + 1078*NO(∂β,NO(β,NO(∂^2γ,NO(γ,NO(γ,γ)))))/9 + 2408*NO(∂β,NO(β,NO(∂γ,NO(∂γ,NO(γ,γ)))))/3 - 2072*NO(∂β,NO(∂^2γ,NO(∂γ,γ)))/9 - 112*NO(∂β,NO(∂^3γ,NO(γ,γ)))/27 + 184*NO(∂β,NO(∂β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,γ)))))))/3 - 628*NO(∂β,NO(∂β,NO(∂γ,NO(γ,NO(γ,γ)))))/3 - 168*NO(∂β,NO(∂γ,NO(∂γ,∂γ))),
#  2*NO(b,NO(c,NO(β,β))) + 3*NO(β,NO(β,NO(β,γ))) + 6*NO(∂β,β),
#  2*NO(b,NO(c,NO(∂^2β,γ))) + 3*NO(b,NO(∂^2c,NO(β,γ))) + 5*NO(b,NO(∂c,NO(∂β,γ))) + NO(β,∂^3γ) + 5*NO(∂^2b,∂c)/2 + 2*NO(∂^2β,∂γ) + 2*NO(∂^3b,c)/3 + 3*NO(∂b,∂^2c) + 5*NO(∂β,∂^2γ)/2,
#  2*NO(b,NO(c,NO(∂β,NO(β,NO(γ,γ))))) - 8*NO(b,NO(c,NO(∂β,∂γ)))/3 - 4*NO(b,NO(∂c,NO(∂β,γ)))/3 + 2*NO(∂b,NO(c,NO(∂β,γ)))/3 + NO(∂β,NO(β,NO(β,NO(γ,NO(γ,γ))))) - 4*NO(∂β,NO(β,NO(∂γ,γ))) + 2*NO(∂β,NO(∂β,NO(γ,γ)))/3 + 10*NO(∂β,∂^2γ)/9,
#  2*NO(b,NO(c,NO(∂β,∂γ))) + 3*NO(b,NO(∂c,NO(β,∂γ))) + NO(β,∂^3γ)/2 + 3*NO(∂^2b,∂c)/2 + NO(∂^3b,c)/3 + 2*NO(∂b,NO(c,NO(∂β,γ))) + 3*NO(∂b,NO(∂c,NO(β,γ))) + NO(∂β,∂^2γ),
#  2*NO(b,∂^3c) + 3*NO(β,∂^3γ) + 6*NO(∂^2b,∂c) + 9*NO(∂^2β,∂γ) + 2*NO(∂^3b,c) + 3*NO(∂^3β,γ) + 6*NO(∂b,∂^2c) + 9*NO(∂β,∂^2γ),
#  2*NO(c,NO(∂^2β,β)) + 3*NO(∂^2c,NO(β,β)) + 5*NO(∂c,NO(∂β,β)),
#  2*NO(c,NO(∂β,∂β)) + 3*NO(∂c,NO(∂β,β)),
#  2*NO(∂b,NO(b,c)) + 3*NO(∂b,NO(β,γ)),
#  216*NO(b,NO(c,NO(β,NO(β,NO(β,NO(γ,NO(γ,γ))))))) - 648*NO(b,NO(c,NO(β,NO(β,NO(∂γ,γ))))) + 108*NO(b,NO(c,NO(β,∂^2γ))) + 108*NO(b,NO(c,NO(∂^2β,γ))) + 648*NO(b,NO(c,NO(∂β,NO(β,NO(γ,γ))))) - 432*NO(b,NO(c,NO(∂β,∂γ))) + 48*NO(b,NO(∂^2c,NO(β,γ))) - 216*NO(b,NO(∂c,NO(β,NO(β,NO(γ,γ))))) + 216*NO(b,NO(∂c,NO(β,∂γ))) - 216*NO(b,NO(∂c,NO(∂β,γ))) - 8*NO(b,∂^3c)/3 + 81*NO(β,NO(β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,γ))))))) - 486*NO(β,NO(β,NO(β,NO(∂γ,NO(γ,γ))))) + 162*NO(β,NO(β,NO(∂^2γ,γ))) + 243*NO(β,NO(β,NO(∂γ,∂γ))) - 27*NO(β,∂^3γ)/2 + 48*NO(∂^2b,NO(c,NO(β,γ))) - 24*NO(∂^2b,∂c) + 162*NO(∂^2β,NO(β,NO(γ,γ))) - 243*NO(∂^2β,∂γ)/2 + 8*NO(∂^3b,c)/3 + 27*NO(∂^3β,γ)/2 + 32*NO(∂b,NO(b,NO(∂c,c))) + 216*NO(∂b,NO(c,NO(β,NO(β,NO(γ,γ))))) - 216*NO(∂b,NO(c,NO(β,∂γ))) + 216*NO(∂b,NO(c,NO(∂β,γ))) - 192*NO(∂b,NO(∂c,NO(β,γ))) + 24*NO(∂b,∂^2c) + 486*NO(∂β,NO(β,NO(β,NO(γ,NO(γ,γ))))) - 1134*NO(∂β,NO(β,NO(∂γ,γ))) + 243*NO(∂β,NO(∂β,NO(γ,γ))) + 243*NO(∂β,∂^2γ)/2,
#  3*NO(b,NO(c,NO(β,∂^2γ))) + NO(b,NO(c,NO(∂^2β,γ))) + 6*NO(b,NO(c,NO(∂β,NO(β,NO(γ,γ))))) - 6*NO(b,NO(∂^2c,NO(β,γ))) + 9*NO(b,NO(∂c,NO(β,NO(β,NO(γ,γ))))) - 6*NO(b,NO(∂c,NO(β,∂γ))) + 9*NO(β,NO(β,NO(∂^2γ,γ)))/2 - 2*NO(β,∂^3γ) + 3*NO(∂^2b,NO(c,NO(β,γ))) + NO(∂^2β,∂γ) + NO(∂^3b,c)/3 - 6*NO(∂b,NO(b,NO(∂c,c))) + 6*NO(∂b,NO(c,NO(∂β,γ))) + 18*NO(∂b,NO(∂c,NO(β,γ))) - 6*NO(∂b,∂^2c) + 6*NO(∂β,NO(β,NO(∂γ,γ))),
#  3*NO(b,NO(β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,NO(γ,γ)))))))) - 29*NO(b,NO(β,NO(β,NO(∂γ,NO(γ,NO(γ,γ)))))) + 40*NO(b,NO(β,NO(∂^2γ,NO(γ,γ))))/3 + 40*NO(b,NO(β,NO(∂γ,NO(∂γ,γ)))) + NO(b,NO(∂^2β,NO(γ,NO(γ,γ)))) - 98*NO(b,NO(∂^2γ,∂γ))/9 - 14*NO(b,NO(∂^3γ,γ))/9 + 8*NO(b,NO(∂β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))) - 70*NO(b,NO(∂β,NO(∂γ,NO(γ,γ))))/3 + 3*NO(∂^2b,NO(b,NO(c,NO(γ,γ)))) + 4*NO(∂^2b,NO(β,NO(γ,NO(γ,γ)))) - 26*NO(∂^2b,NO(∂γ,γ))/3 + NO(∂^3b,NO(γ,γ))/3 + 10*NO(∂b,NO(b,NO(c,NO(β,NO(γ,NO(γ,γ)))))) - 62*NO(∂b,NO(b,NO(c,NO(∂γ,γ))))/3 - 4*NO(∂b,NO(b,NO(∂c,NO(γ,γ)))) + 9*NO(∂b,NO(β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))) - 48*NO(∂b,NO(β,NO(∂γ,NO(γ,γ)))) + 34*NO(∂b,NO(∂^2γ,γ))/3 + 8*NO(∂b,NO(∂β,NO(γ,NO(γ,γ)))) + 58*NO(∂b,NO(∂γ,∂γ))/3,
#  3*NO(b,NO(β,NO(β,NO(∂γ,NO(γ,NO(γ,γ)))))) - 5*NO(b,NO(β,NO(∂^2γ,NO(γ,γ)))) - 8*NO(b,NO(β,NO(∂γ,NO(∂γ,γ)))) + 2*NO(b,NO(∂^2β,NO(γ,NO(γ,γ))))/3 + 14*NO(b,NO(∂^2γ,∂γ))/3 + 14*NO(b,NO(∂^3γ,γ))/9 + 2*NO(b,NO(∂β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))) - 14*NO(b,NO(∂β,NO(∂γ,NO(γ,γ))))/3 + NO(∂^2b,NO(b,NO(c,NO(γ,γ))))/3 + NO(∂^2b,NO(β,NO(γ,NO(γ,γ)))) - 2*NO(∂^2b,NO(∂γ,γ)) + 2*NO(∂^3b,NO(γ,γ))/9 - 2*NO(∂b,NO(b,NO(c,NO(β,NO(γ,NO(γ,γ)))))) + 6*NO(∂b,NO(b,NO(c,NO(∂γ,γ)))) + 8*NO(∂b,NO(b,NO(∂c,NO(γ,γ))))/3 + 4*NO(∂b,NO(β,NO(∂γ,NO(γ,γ)))) - 11*NO(∂b,NO(∂^2γ,γ))/3 + 2*NO(∂b,NO(∂β,NO(γ,NO(γ,γ)))) - 2*NO(∂b,NO(∂γ,∂γ)),
#  3*NO(b,NO(β,∂γ)) + 3*NO(b,NO(∂β,γ)) - 2*NO(∂b,NO(b,c)),
#  36*NO(b,NO(c,NO(β,NO(β,NO(∂γ,γ))))) - 18*NO(b,NO(c,NO(β,∂^2γ))) + 18*NO(b,NO(c,NO(∂^2β,γ))) + 36*NO(b,NO(c,NO(∂β,NO(β,NO(γ,γ))))) - 12*NO(b,NO(∂^2c,NO(β,γ))) + 18*NO(b,NO(∂c,NO(β,NO(β,NO(γ,γ))))) - 30*NO(b,NO(∂c,NO(β,∂γ))) + 6*NO(b,NO(∂c,NO(∂β,γ))) + 4*NO(b,∂^3c)/3 + 27*NO(β,NO(β,NO(β,NO(∂γ,NO(γ,γ))))) - 27*NO(β,NO(β,NO(∂^2γ,γ))) - 27*NO(β,NO(β,NO(∂γ,∂γ))) + 9*NO(β,∂^3γ)/2 + 12*NO(∂^2b,NO(c,NO(β,γ))) - 4*NO(∂^2b,∂c) + 27*NO(∂^2β,NO(β,NO(γ,γ))) - 27*NO(∂^2β,∂γ)/2 + 4*NO(∂^3b,c)/3 + 9*NO(∂^3β,γ)/2 + 18*NO(∂b,NO(c,NO(β,NO(β,NO(γ,γ))))) - 6*NO(∂b,NO(c,NO(β,∂γ))) + 30*NO(∂b,NO(c,NO(∂β,γ))) - 4*NO(∂b,∂^2c) + 27*NO(∂β,NO(β,NO(β,NO(γ,NO(γ,γ))))) + 27*NO(∂β,NO(∂β,NO(γ,γ))) - 27*NO(∂β,∂^2γ)/2,
#  4*NO(b,NO(c,NO(β,NO(β,NO(∂γ,γ))))) - 8*NO(b,NO(c,NO(β,∂^2γ)))/3 + 2*NO(b,NO(c,NO(∂β,NO(β,NO(γ,γ))))) - 4*NO(b,NO(∂^2c,NO(β,γ)))/3 + 2*NO(b,NO(∂c,NO(β,NO(β,NO(γ,γ))))) - 4*NO(b,NO(∂c,NO(β,∂γ))) + 3*NO(β,NO(β,NO(β,NO(∂γ,NO(γ,γ))))) - 4*NO(β,NO(β,NO(∂^2γ,γ))) - 4*NO(β,NO(β,NO(∂γ,∂γ))) + 10*NO(β,∂^3γ)/9 + 2*NO(∂^2b,NO(c,NO(β,γ)))/3 + 2*NO(∂^2β,NO(β,NO(γ,γ)))/3 + 2*NO(∂b,NO(c,NO(β,NO(β,NO(γ,γ))))) - 2*NO(∂b,NO(c,NO(β,∂γ))) - 2*NO(∂b,NO(∂c,NO(β,γ)))/3 + 2*NO(∂β,NO(β,NO(β,NO(γ,NO(γ,γ))))) - 8*NO(∂β,NO(β,NO(∂γ,γ)))/3,
#  6*NO(∂^2c,NO(c,NO(∂β,β))) + 9*NO(∂^2c,NO(∂c,NO(β,β))) - 6*NO(∂c,NO(c,NO(∂^2β,β))) + 10*NO(∂c,NO(c,NO(∂β,∂β))),
#  9*NO(b,NO(β,NO(β,NO(γ,γ)))) - 9*NO(b,NO(β,∂γ)) + 9*NO(b,NO(∂β,γ)) - 4*NO(∂b,NO(b,c)),
#  ∂^2b/2 + NO(b,NO(β,∂γ)) + NO(∂b,NO(β,γ)),
#  ∂^5c/3 - 4*NO(b,NO(∂^2c,NO(c,NO(β,∂γ)))) - 4*NO(b,NO(∂^2c,NO(c,NO(∂β,γ))))/3 - 2*NO(b,NO(∂^2c,NO(∂c,NO(β,γ)))) - 8*NO(b,NO(∂^3c,NO(c,NO(β,γ))))/3 + 20*NO(b,NO(∂^3c,∂c))/9 + 10*NO(b,NO(∂^4c,c))/9 + 6*NO(b,NO(∂c,NO(c,NO(β,NO(β,NO(∂γ,γ)))))) - 5*NO(b,NO(∂c,NO(c,NO(β,∂^2γ)))) - 7*NO(b,NO(∂c,NO(c,NO(∂^2β,γ))))/3 - 2*NO(b,NO(∂c,NO(c,NO(∂β,NO(β,NO(γ,γ)))))) + 16*NO(b,NO(∂c,NO(c,NO(∂β,∂γ))))/3 - NO(c,NO(∂^2β,NO(β,NO(∂γ,γ)))) + NO(c,NO(∂^2β,NO(∂β,NO(γ,γ))))/6 + 5*NO(c,NO(∂^2β,∂^2γ))/6 + NO(c,NO(∂^3β,NO(β,NO(γ,γ))))/2 - 2*NO(c,NO(∂^3β,∂γ))/3 + 5*NO(c,NO(∂^4β,γ))/36 - 3*NO(c,NO(∂β,NO(β,NO(β,NO(∂γ,NO(γ,γ)))))) + 5*NO(c,NO(∂β,NO(β,NO(∂^2γ,γ)))) + 4*NO(c,NO(∂β,NO(β,NO(∂γ,∂γ)))) - NO(c,NO(∂β,NO(∂β,NO(β,NO(γ,NO(γ,γ)))))) + 4*NO(c,NO(∂β,NO(∂β,NO(∂γ,γ))))/3 - 14*NO(c,NO(∂β,∂^3γ))/9 + 6*NO(∂^2c,NO(β,NO(β,NO(∂γ,γ)))) - 5*NO(∂^2c,NO(β,∂^2γ)) + 5*NO(∂^2c,NO(∂β,NO(β,NO(γ,γ)))) - 4*NO(∂^2c,NO(∂β,∂γ)) - NO(∂^3b,NO(∂c,c))/9 + 2*NO(∂^3c,NO(β,NO(β,NO(γ,γ)))) - 13*NO(∂^3c,NO(β,∂γ))/3 - 5*NO(∂^3c,NO(∂β,γ))/9 - 5*NO(∂^4c,NO(β,γ))/3 - 4*NO(∂b,NO(∂^2c,NO(c,NO(β,γ)))) + NO(∂b,NO(∂^2c,∂c)) + 2*NO(∂b,NO(∂^3c,c))/3 + 3*NO(∂b,NO(∂c,NO(c,NO(β,NO(β,NO(γ,γ)))))) - 3*NO(∂b,NO(∂c,NO(c,NO(β,∂γ)))) + NO(∂b,NO(∂c,NO(c,NO(∂β,γ))))/3 - 9*NO(∂c,NO(β,NO(β,NO(β,NO(∂γ,NO(γ,γ))))))/2 + 15*NO(∂c,NO(β,NO(β,NO(∂^2γ,γ))))/2 + 6*NO(∂c,NO(β,NO(β,NO(∂γ,∂γ)))) - 7*NO(∂c,NO(β,∂^3γ))/3 + 3*NO(∂c,NO(∂^2β,NO(β,NO(γ,γ))))/2 - NO(∂c,NO(∂^2β,∂γ)) - 3*NO(∂c,NO(∂β,NO(β,NO(β,NO(γ,NO(γ,γ))))))/2 + 2*NO(∂c,NO(∂β,NO(β,NO(∂γ,γ)))),
#  2*∂^5c/3 + 36*NO(b,NO(∂^2c,NO(c,NO(β,NO(β,NO(γ,γ)))))) + 80*NO(b,NO(∂^2c,NO(c,NO(∂β,γ)))) + 88*NO(b,NO(∂^3c,NO(c,NO(β,γ))))/3 - 56*NO(b,NO(∂^3c,∂c))/9 - 52*NO(b,NO(∂^4c,c))/9 - 72*NO(b,NO(∂c,NO(c,NO(β,NO(β,NO(β,NO(γ,NO(γ,γ)))))))) + 132*NO(b,NO(∂c,NO(c,NO(β,NO(β,NO(∂γ,γ)))))) + 6*NO(b,NO(∂c,NO(c,NO(β,∂^2γ)))) - 158*NO(b,NO(∂c,NO(c,NO(∂^2β,γ))))/3 - 284*NO(b,NO(∂c,NO(c,NO(∂β,NO(β,NO(γ,γ)))))) + 440*NO(b,NO(∂c,NO(c,NO(∂β,∂γ))))/3 + 48*NO(c,NO(∂^2β,NO(β,NO(β,NO(γ,NO(γ,γ)))))) - 110*NO(c,NO(∂^2β,NO(β,NO(∂γ,γ)))) + 93*NO(c,NO(∂^2β,NO(∂β,NO(γ,γ)))) + 5*NO(c,NO(∂^2β,∂^2γ))/3 + 27*NO(c,NO(∂^3β,NO(β,NO(γ,γ)))) - 80*NO(c,NO(∂^3β,∂γ))/3 + 23*NO(c,NO(∂^4β,γ))/6 + 18*NO(c,NO(∂β,NO(β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))))) - 66*NO(c,NO(∂β,NO(β,NO(β,NO(∂γ,NO(γ,γ)))))) - 6*NO(c,NO(∂β,NO(β,NO(∂^2γ,γ)))) + 20*NO(c,NO(∂β,NO(β,NO(∂γ,∂γ)))) + 78*NO(c,NO(∂β,NO(∂β,NO(β,NO(γ,NO(γ,γ)))))) - 80*NO(c,NO(∂β,NO(∂β,NO(∂γ,γ)))) + 4*NO(c,NO(∂β,∂^3γ))/3 + 20*NO(∂^2b,NO(∂^2c,c)) - 44*NO(∂^2b,NO(∂c,NO(c,NO(β,γ)))) - 18*NO(∂^2c,NO(β,NO(β,NO(β,NO(γ,NO(γ,γ)))))) + 10*NO(∂^2c,NO(β,∂^2γ)) - 50*NO(∂^2c,NO(∂^2β,γ)) - 120*NO(∂^2c,NO(∂β,NO(β,NO(γ,γ)))) + 32*NO(∂^2c,NO(∂β,∂γ)) - 32*NO(∂^3b,NO(∂c,c))/9 - 22*NO(∂^3c,NO(β,NO(β,NO(γ,γ)))) + 50*NO(∂^3c,NO(β,∂γ))/3 - 82*NO(∂^3c,NO(∂β,γ))/3 + 26*NO(∂^4c,NO(β,γ))/3 + 60*NO(∂b,NO(∂^2c,NO(c,NO(β,γ)))) - 8*NO(∂b,NO(∂^2c,∂c)) + 40*NO(∂b,NO(∂^3c,c))/3 - 114*NO(∂b,NO(∂c,NO(c,NO(β,NO(β,NO(γ,γ)))))) + 70*NO(∂b,NO(∂c,NO(c,NO(β,∂γ)))) - 150*NO(∂b,NO(∂c,NO(c,NO(∂β,γ)))) + 27*NO(∂c,NO(β,NO(β,NO(β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))))) - 99*NO(∂c,NO(β,NO(β,NO(β,NO(∂γ,NO(γ,γ)))))) - 9*NO(∂c,NO(β,NO(β,NO(∂^2γ,γ)))) + 30*NO(∂c,NO(β,NO(β,NO(∂γ,∂γ)))) + 2*NO(∂c,NO(β,∂^3γ)) + 67*NO(∂c,NO(∂^2β,NO(β,NO(γ,γ)))) - 42*NO(∂c,NO(∂^2β,∂γ)) - 8*NO(∂c,NO(∂^3β,γ))/3 + 207*NO(∂c,NO(∂β,NO(β,NO(β,NO(γ,NO(γ,γ)))))) - 340*NO(∂c,NO(∂β,NO(β,NO(∂γ,γ)))) + 130*NO(∂c,NO(∂β,NO(∂β,NO(γ,γ)))) + 20*NO(∂c,NO(∂β,∂^2γ))/3,
#  NO(b,NO(β,NO(β,NO(∂γ,NO(γ,NO(γ,γ)))))) - NO(b,NO(β,NO(∂^2γ,NO(γ,γ)))) - 4*NO(b,NO(β,NO(∂γ,NO(∂γ,γ)))) + 22*NO(b,NO(∂^2γ,∂γ))/9 + 2*NO(b,NO(∂^3γ,γ))/9 + 2*NO(b,NO(∂β,NO(∂γ,NO(γ,γ))))/3 + NO(∂^2b,NO(b,NO(c,NO(γ,γ)))) + NO(∂^2b,NO(β,NO(γ,NO(γ,γ)))) - 2*NO(∂^2b,NO(∂γ,γ)) + NO(∂^3b,NO(γ,γ))/9 + 2*NO(∂b,NO(b,NO(c,NO(β,NO(γ,NO(γ,γ)))))) - 10*NO(∂b,NO(b,NO(c,NO(∂γ,γ))))/3 - 4*NO(∂b,NO(b,NO(∂c,NO(γ,γ))))/3 + NO(∂b,NO(β,NO(β,NO(γ,NO(γ,NO(γ,γ)))))) - 4*NO(∂b,NO(β,NO(∂γ,NO(γ,γ)))) + 7*NO(∂b,NO(∂^2γ,γ))/9 + 2*NO(∂b,NO(∂β,NO(γ,NO(γ,γ))))/3,
#  NO(∂b, NO(b,NO(γ,γ))),
#  NO(∂β, β)]

# %%
weight = 8
# basis = LocalOperatorBasis(generators)


# # 用 b, c, β, γ 所生成的算符空间
# bc_basis = LocalOperatorBasis([b, c, β, γ], max_occurence=6)

# 列举 weight=4 的算符，有 10 个
list_of_ops = [op for op in basis.list(weight=weight)]
# list_of_ops_realized = [op.realize() for op in basis.list(weight=weight)]
# len(list_of_ops)

# %%
from pyope.local_operator import collect_operators_coefficients
collect_operators_coefficients(list_of_ops[3])
# Out:
# {NO(∂G, Wbar): 1}

# %%
# 用 generators 所生成的算符空间
# set_compute_backend("wolfram")
weight = 4
basis = LocalOperatorBasis(generators)

bc_basis = LocalOperatorBasis([b, c, β, γ], max_occurence=6)


list_of_ops = [op for op in basis.list(weight=weight)]
list_of_ops_realized = [op.realize() for op in basis.list(weight=weight)]
len(list_of_ops)

list_of_ops_realized = simplify_with_wolfram(list_of_ops_realized)

independents = bc_basis.list_independent_ops(list_of_ops_realized)
independents_indices = bc_basis.list_independent_op_indices(
    list_of_ops_realized)
relations = bc_basis.list_zero_relations(list_of_ops_realized)

# %%
null = sum([relations[6]["coefficients"][i] * list_of_ops[i]
           for i in range(len(list_of_ops_realized))])
null
