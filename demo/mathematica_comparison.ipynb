# %% [markdown]
# # PyOPE vs Mathematica OPEdefs 对比测试
#
# 本 notebook 用于对比 PyOPE 和 Mathematica OPEdefs.m 的计算结果，验证 Python 实现的正确性。
#
# ## 测试策略
#
# 1. 使用 `wolframscript` 运行 Mathematica 代码
# 2. 使用 PyOPE 运行相同的计算
# 3. 对比两者的结果

# %%
from pyope import *

# %% [markdown]
# ## 辅助函数：运行 Mathematica 代码

# %%
def run_mathematica(code: str) -> str:
    """
    使用 wolframscript 运行 Mathematica 代码
    
    Args:
        code: Mathematica 代码字符串
    
    Returns:
        输出结果字符串
    """
    try:
        result = subprocess.run(
            ['wolframscript', '-code', code],
            capture_output=True,
            text=True,
            timeout=30
        )
        if result.returncode != 0:
            print(f"错误: {result.stderr}")
            return None
        return result.stdout.strip()
    except subprocess.TimeoutExpired:
        print("Mathematica 执行超时")
        return None
    except Exception as e:
        print(f"执行出错: {e}")
        return None

# 测试 wolframscript
test_result = run_mathematica("2 + 2")
print(f"测试 Mathematica: 2 + 2 = {test_result}")
# Out:
# 测试 Mathematica: 2 + 2 = 4

# %% [markdown]
# ## 测试 1: 基本 OPE 定义和计算
#
# 测试 Virasoro 代数的 OPE: T(z)T(w)

# %%
# Mathematica 代码
mathematica_code = """
Get["/Users/lelouch/pyope/OPEdefs/OPEdefs.m"];
Bosonic[T];
OPE[T, T] = MakeOPE[{c/2 One, 0, 2 T, T'}];
result = OPE[T, T];
Print[result]
"""

print("=== Mathematica 结果 ===")
mathematica_result = run_mathematica(mathematica_code)
print(mathematica_result)
print()

# PyOPE 代码
print("=== PyOPE 结果 ===")
T = BasisOperator("T",  conformal_weight=2)
Bosonic(T)
c = sp.Symbol('c')

OPE[T, T] = MakeOPE([c/2 * One, 0, 2*T, d(T)])
pyope_result = OPE(T, T)

print(f"最高极点: {pyope_result.max_pole}")
for q in range(pyope_result.max_pole, 0, -1):
    pole_q = pyope_result.pole(q)
    if pole_q != 0:
        print(f"  pole({q}): {pole_q}")
# Out:
# === Mathematica 结果 ===
# OPEdefs Version 3.1 (beta 4) by Kris Thielemans
# Type ?OPEdefsHelp for a primer on OPEdefs.
# OPEData[{(c*One)/2, 0, 2*T, Derivative[1][T]}]
# Null
#
# === PyOPE 结果 ===
# 最高极点: 4
#   pole(4): One*c/2
#   pole(2): 2*T
#   pole(1): ∂T

# %% [markdown]
# ## 测试 2: 正规序乘积
#
# 测试 NO(T, T) 的计算

# %%
# Mathematica 代码
mathematica_code = """
Get["/Users/lelouch/pyope/OPEdefs/OPEdefs.m"];
Bosonic[T];
result = NO[T, T];
Print[result]
"""

print("=== Mathematica 结果 ===")
mathematica_result = run_mathematica(mathematica_code)
print(mathematica_result)
print()

# PyOPE 代码
print("=== PyOPE 结果 ===")
no_TT = NO(T, T)
print(f"NO(T, T) = {no_TT}")
# Out:
# === Mathematica 结果 ===
# OPEdefs Version 3.1 (beta 4) by Kris Thielemans
# Type ?OPEdefsHelp for a primer on OPEdefs.
# NO[T, T]
# Null
#
# === PyOPE 结果 ===
# NO(T, T) = NO(T,T)

# %% [markdown]
# ## 测试 3: 左侧复合算符的 OPE
#
# 测试 OPE(NO(J,J), J) - 这是我们刚刚完善的功能

# %%
# Mathematica 代码
mathematica_code = """
Get["/Users/lelouch/pyope/OPEdefs/OPEdefs.m"];
Bosonic[J];
OPE[J, J] = MakeOPE[{k One, 0}];
result = OPE[NO[J, J], J];
Print["MaxPole: ", MaxPole[result]];
Print["Pole 2: ", OPEPole[2][result]];
Print["Pole 1: ", OPEPole[1][result]];
"""

print("=== Mathematica 结果 ===")
mathematica_result = run_mathematica(mathematica_code)
print(mathematica_result)
print()

# PyOPE 代码
print("=== PyOPE 结果 ===")
J = BasisOperator("J",  conformal_weight=1)
Bosonic(J)
k = sp.Symbol('k')

OPE[J, J] = MakeOPE([k * One, 0])
no_JJ = NO(J, J)
pyope_result = OPE(no_JJ, J)

print(f"MaxPole: {pyope_result.max_pole}")
print(f"Pole 2: {pyope_result.pole(2)}")
print(f"Pole 1: {pyope_result.pole(1)}")
# Out:
# === Mathematica 结果 ===
# OPEdefs Version 3.1 (beta 4) by Kris Thielemans
# Type ?OPEdefsHelp for a primer on OPEdefs.
# MaxPole: 2
# Pole 2: 2*J*k
# Pole 1: 2*k*Derivative[1][J]
# Null
#
# === PyOPE 结果 ===
# MaxPole: 2
# Pole 2: 2*J*k
# Pole 1: 2*∂J*k

# %% [markdown]
# ## 测试 4: 导数算符的 OPE
#
# 测试 OPE(∂T, T)

# %%
# Mathematica 代码
mathematica_code = """
Get["/Users/lelouch/pyope/OPEdefs/OPEdefs.m"];
Bosonic[T];
OPE[T, T] = MakeOPE[{c/2 One, 0, 2 T, T'}];
result = OPE[T', T];
Print["MaxPole: ", MaxPole[result]];
Do[Print["Pole ", i, ": ", OPEPole[i][result]], {i, MaxPole[result], 1, -1}];
"""

print("=== Mathematica 结果 ===")
mathematica_result = run_mathematica(mathematica_code)
print(mathematica_result)
print()

# PyOPE 代码
print("=== PyOPE 结果 ===")
dT = d(T)
pyope_result = OPE(dT, T)

print(f"MaxPole: {pyope_result.max_pole}")
for q in range(pyope_result.max_pole, 0, -1):
    pole_q = pyope_result.pole(q)
    if pole_q != 0:
        print(f"Pole {q}: {pole_q}")
# Out:
# === Mathematica 结果 ===
# OPEdefs Version 3.1 (beta 4) by Kris Thielemans
# Type ?OPEdefsHelp for a primer on OPEdefs.
# MaxPole: 5
# Pole 5: -2*c*One
# Pole 4: 0
# Pole 3: -4*T
# Pole 2: -Derivative[1][T]
# Pole 1: 0
# Null
#
# === PyOPE 结果 ===
# MaxPole: 5
# Pole 5: -2*One*c
# Pole 3: -4*T
# Pole 2: -∂T

# %% [markdown]
# ## 测试 5: 混合算符的左侧复合 OPE
#
# 测试 OPE(NO(T,J), J)

# %%
# Mathematica 代码
mathematica_code = """
Get["/Users/lelouch/pyope/OPEdefs/OPEdefs.m"];
Bosonic[T, J];
OPE[T, T] = MakeOPE[{c/2 One, 0, 2 T, T'}];
OPE[J, J] = MakeOPE[{k One, 0}];
OPE[T, J] = MakeOPE[{J, J'}];
result = OPE[NO[T, J], J];
Print["MaxPole: ", MaxPole[result]];
Print["Pole 2: ", OPEPole[2][result]];
Print["Pole 1: ", OPEPole[1][result]];
"""

print("=== Mathematica 结果 ===")
mathematica_result = run_mathematica(mathematica_code)
print(mathematica_result)
print()

# PyOPE 代码
print("=== PyOPE 结果 ===")
# 重新定义算符（避免之前的定义干扰）
T2 = BasisOperator("T",  conformal_weight=2)
J2 = BasisOperator("J",  conformal_weight=1)
Bosonic(T2, J2)

OPE[T2, T2] = MakeOPE([c/2 * One, 0, 2*T2, d(T2)])
OPE[J2, J2] = MakeOPE([k * One, 0])
OPE[T2, J2] = MakeOPE([J2, d(J2)])

no_TJ = NO(T2, J2)
pyope_result = OPE(no_TJ, J2)

print(f"MaxPole: {pyope_result.max_pole}")
print(f"Pole 2: {pyope_result.pole(2)}")
print(f"Pole 1: {pyope_result.pole(1)}")
# Out:
# === Mathematica 结果 ===
# OPEdefs Version 3.1 (beta 4) by Kris Thielemans
# Type ?OPEdefsHelp for a primer on OPEdefs.
# MaxPole: 4
# Pole 2: k*T + NO[J, J]
# Pole 1: 2*NO[Derivative[1][J], J] + k*Derivative[1][T]
# Null
#
# === PyOPE 结果 ===
# MaxPole: 4
# Pole 2: T*k + NO(J,J)
# Pole 1: ∂T*k + NO(J,∂J) + NO(∂J,J)
# /Users/lelouch/pyope/src/pyope/registry.py:61: UserWarning: Operator T is already registered, overwriting parity
#   warnings.warn(
# /Users/lelouch/pyope/src/pyope/registry.py:61: UserWarning: Operator J is already registered, overwriting parity
#   warnings.warn(

# %% [markdown]
# ## 测试 6: Sugawara 构造
#
# 测试 TSugawara = NO(J,J) 的 OPE(TSugawara, TSugawara)

# %%
# Mathematica 代码
mathematica_code = """
Get["/Users/lelouch/pyope/OPEdefs/OPEdefs.m"];
Bosonic[J];
OPE[J, J] = MakeOPE[{One, 0}];
TSugawara = NO[J, J];
result = OPE[TSugawara, TSugawara];
Print["MaxPole: ", MaxPole[result]];
Do[Print["Pole ", i, ": ", OPEPole[i][result]], {i, MaxPole[result], 1, -1}];
"""

print("=== Mathematica 结果 ===")
mathematica_result = run_mathematica(mathematica_code)
print(mathematica_result)
print()

# PyOPE 代码
print("=== PyOPE 结果 ===")
# 重新定义 J 以避免干扰
J3 = BasisOperator("J",  conformal_weight=1)
Bosonic(J3)

OPE[J3, J3] = MakeOPE([One, 0])
TSugawara = NO(J3, J3)
pyope_result = OPE(TSugawara, TSugawara)

print(f"MaxPole: {pyope_result.max_pole}")
for q in range(pyope_result.max_pole, 0, -1):
    pole_q = pyope_result.pole(q)
    if pole_q != 0:
        print(f"Pole {q}: {pole_q}")
# Out:
# === Mathematica 结果 ===
# OPEdefs Version 3.1 (beta 4) by Kris Thielemans
# Type ?OPEdefsHelp for a primer on OPEdefs.
# MaxPole: 4
# Pole 4: 2*One
# Pole 3: 0
# Pole 2: 4*NO[J, J]
# Pole 1: 4*NO[Derivative[1][J], J]
# Null
#
# === PyOPE 结果 ===
# MaxPole: 4
# Pole 4: 2*One*k**2
# Pole 2: 4*NO(J,J)*k
# Pole 1: 2*NO(J,∂J)*k + 2*NO(∂J,J)*k
# /Users/lelouch/pyope/src/pyope/registry.py:61: UserWarning: Operator J is already registered, overwriting parity
#   warnings.warn(

# %% [markdown]
# ## 测试 7: 高阶导数算符 OPE
#
# 测试 OPE(T, J'') - 二阶导数的 OPE

# %%
# Mathematica 代码
mathematica_code = """
Get["/Users/lelouch/pyope/OPEdefs/OPEdefs.m"];
Bosonic[T, J];
OPE[T, T] = MakeOPE[{c/2 One, 0, 2 T, T'}];
OPE[J, J] = MakeOPE[{k One, 0}];
OPE[T, J] = MakeOPE[{J, J'}];
result = OPE[T, J''];
Print["MaxPole: ", MaxPole[result]];
Do[Print["Pole ", i, ": ", OPEPole[i][result]], {i, MaxPole[result], 1, -1}];
"""

print("=== Mathematica 结果 ===")
mathematica_result = run_mathematica(mathematica_code)
print(mathematica_result)
print()

# PyOPE 代码
print("=== PyOPE 结果 ===")
# 重新定义算符
T4 = BasisOperator("T",  conformal_weight=2)
J4 = BasisOperator("J",  conformal_weight=1)
Bosonic(T4, J4)

OPE[T4, T4] = MakeOPE([c/2 * One, 0, 2*T4, d(T4)])
OPE[J4, J4] = MakeOPE([k * One, 0])
OPE[T4, J4] = MakeOPE([J4, d(J4)])

# 计算二阶导数的 OPE
dJ4_2 = d(J4, 2)  # J''
pyope_result = OPE(T4, dJ4_2)

print(f"MaxPole: {pyope_result.max_pole}")
for q in range(pyope_result.max_pole, 0, -1):
    pole_q = pyope_result.pole(q)
    if pole_q != 0:
        print(f"Pole {q}: {pole_q}")

# %% [markdown]
# ## 测试 8: OPE 的反对称性
#
# 测试 OPE(T,J) - OPE(J,T) 应该给出一个特定的结果

# %%
# Mathematica 代码
mathematica_code = """
Get["/Users/lelouch/pyope/OPEdefs/OPEdefs.m"];
Bosonic[T, J];
OPE[T, T] = MakeOPE[{c/2 One, 0, 2 T, T'}];
OPE[J, J] = MakeOPE[{k One, 0}];
OPE[T, J] = MakeOPE[{J, J'}];
result = OPE[T, J] - OPE[J, T];
Print["MaxPole: ", MaxPole[result]];
Do[Print["Pole ", i, ": ", OPEPole[i][result]], {i, MaxPole[result], 1, -1}];
"""

print("=== Mathematica 结果 ===")
mathematica_result = run_mathematica(mathematica_code)
print(mathematica_result)
print()

# PyOPE 代码
print("=== PyOPE 结果 ===")
# 重新定义算符
T5 = BasisOperator("T",  conformal_weight=2)
J5 = BasisOperator("J",  conformal_weight=1)
Bosonic(T5, J5)

OPE[T5, T5] = MakeOPE([c/2 * One, 0, 2*T5, d(T5)])
OPE[J5, J5] = MakeOPE([k * One, 0])
OPE[T5, J5] = MakeOPE([J5, d(J5)])

# 计算反对称性
pyope_result = OPE(T5, J5) - OPE(J5, T5)

print(f"MaxPole: {pyope_result.max_pole}")
for q in range(pyope_result.max_pole, 0, -1):
    pole_q = pyope_result.pole(q)
    if pole_q != 0:
        print(f"Pole {q}: {pole_q}")
# Out:
# === Mathematica 结果 ===
# OPEdefs Version 3.1 (beta 4) by Kris Thielemans
# Type ?OPEdefsHelp for a primer on OPEdefs.
# MaxPole: 1
# Pole 1: Derivative[1][J]
# Null
#
# === PyOPE 结果 ===
# MaxPole: 1
# Pole 1: ∂J
# /Users/lelouch/pyope/src/pyope/registry.py:61: UserWarning: Operator T is already registered, overwriting parity
#   warnings.warn(
# /Users/lelouch/pyope/src/pyope/registry.py:61: UserWarning: Operator J is already registered, overwriting parity
#   warnings.warn(

# %% [markdown]
# ## 测试 9: 嵌套正规序乘积 - NO(NO(T,J), J)
#
# 测试嵌套的正规序乘积的 OPE

# %%
# Mathematica 代码
mathematica_code = """
Get["/Users/lelouch/pyope/OPEdefs/OPEdefs.m"];
Bosonic[T, J];
OPE[T, T] = MakeOPE[{c/2 One, 0, 2 T, T'}];
OPE[J, J] = MakeOPE[{k One, 0}];
OPE[T, J] = MakeOPE[{J, J'}];
result = NO[NO[T, J], J];
Print["Result: ", result];
"""

print("=== Mathematica 结果 ===")
mathematica_result = run_mathematica(mathematica_code)
print(mathematica_result)
print()

# PyOPE 代码
print("=== PyOPE 结果 ===")
# 重新定义算符
T6 = BasisOperator("T",  conformal_weight=2)
J6 = BasisOperator("J",  conformal_weight=1)
Bosonic(T6, J6)

OPE[T6, T6] = MakeOPE([c/2 * One, 0, 2*T6, d(T6)])
OPE[J6, J6] = MakeOPE([k * One, 0])
OPE[T6, J6] = MakeOPE([J6, d(J6)])

# 嵌套正规序
no_TJ = NO(T6, J6)
result = simplify(NO(no_TJ, J6))

print(f"Result: {result}")
# Out:
# === Mathematica 结果 ===
# OPEdefs Version 3.1 (beta 4) by Kris Thielemans
# Type ?OPEdefsHelp for a primer on OPEdefs.
# Result: NO[T, NO[J, J]] + NO[Derivative[1][J], Derivative[1][J]] + NO[Derivative[2][J], J]/2 + (k*Derivative[2][T])/2
# Null
#
# === PyOPE 结果 ===
# Result: ∂^2T*k/2 + NO(T,NO(J,J)) + NO(∂J,∂J) + NO(∂^2J,J)/2
# /Users/lelouch/pyope/src/pyope/registry.py:61: UserWarning: Operator T is already registered, overwriting parity
#   warnings.warn(
# /Users/lelouch/pyope/src/pyope/registry.py:61: UserWarning: Operator J is already registered, overwriting parity
#   warnings.warn(

# %% [markdown]
# ## 测试 10: 双重嵌套正规序 - NO(NO(T,J), NO(T,J))
#
# 测试更复杂的嵌套正规序乘积

# %%
# Mathematica 代码
mathematica_code = """
Get["/Users/lelouch/pyope/OPEdefs/OPEdefs.m"];
Bosonic[T, J];
OPE[T, T] = MakeOPE[{c/2 One, 0, 2 T, T'}];
OPE[J, J] = MakeOPE[{k One, 0}];
OPE[T, J] = MakeOPE[{J, J'}];
result = NO[NO[T, J], NO[T, J]];
Print["Result: ", result];
"""

print("=== Mathematica 结果 ===")
mathematica_result = run_mathematica(mathematica_code)
print(mathematica_result)
print()

# PyOPE 代码
print("=== PyOPE 结果 ===")
# 重新定义算符
T7 = BasisOperator("T",  conformal_weight=2)
J7 = BasisOperator("J",  conformal_weight=1)
Bosonic(T7, J7)

OPE[T7, T7] = MakeOPE([c/2 * One, 0, 2*T7, d(T7)])
OPE[J7, J7] = MakeOPE([k * One, 0])
OPE[T7, J7] = MakeOPE([J7, d(J7)])

# 双重嵌套正规序
no_TJ1 = NO(T7, J7)
no_TJ2 = NO(T7, J7)
result = simplify(NO(no_TJ1, no_TJ2))

print(f"Result: {result}")
# Out:
# === Mathematica 结果 ===
# OPEdefs Version 3.1 (beta 4) by Kris Thielemans
# Type ?OPEdefsHelp for a primer on OPEdefs.
# Result: NO[T, NO[T, NO[J, J]]] + NO[T, NO[Derivative[1][J], Derivative[1][J]]] + NO[T, NO[Derivative[2][J], J]] + NO[Derivative[1][T], NO[Derivative[1][J], J]] + (k*NO[Derivative[2][T], T])/2 + NO[Derivative[2][T], NO[J, J]]/2 + NO[Derivative[3][J], Derivative[1][J]]/6 + (-7/24 + c/48)*NO[Derivative[4][J], J] + (k*Derivative[4][T])/8
# Null
#
# === PyOPE 结果 ===
# Result: ∂^4T*k/8 + NO(T,NO(T,NO(J,J))) + NO(T,NO(∂J,∂J)) + NO(T,NO(∂^2J,J)) + NO(∂T,NO(∂J,J)) + NO(∂^2T,NO(J,J))/2 + NO(∂^2T,T)*k/2 + NO(∂^3J,∂J)/6 + NO(∂^4J,J)*c/48 - 7*NO(∂^4J,J)/24
# /Users/lelouch/pyope/src/pyope/registry.py:61: UserWarning: Operator T is already registered, overwriting parity
#   warnings.warn(
# /Users/lelouch/pyope/src/pyope/registry.py:61: UserWarning: Operator J is already registered, overwriting parity
#   warnings.warn(
